# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = [1,2,3]
y = [4,5,6]

# %%
plt.plot(x,y)
plt.grid()
plt.show()

# %%
# Pyplot API

# %%
#Univariate - Numerical

# %%
data = {
    "Salary":[25000, 30000, 37000, 28000, 39000, 48000, 60000, 55000, 58000]
}

# %%
df = pd.DataFrame(data)

# %%
df.head()
# Out:
#    Salary
# 0   25000
# 1   30000
# 2   37000
# 3   28000
# 4   39000

# %%
df.shape
# Out:
# (9, 1)

# %%
# Line Plot:
plt.plot(df["Salary"])
plt.show()

# %%
plt.plot(df["Salary"], color = "red", marker = "*",linestyle = ":",linewidth = "2")
plt.grid()
plt.show()

# %%
# Histogram
plt.hist(df["Salary"], bins = 5, color = "green")
plt.show()

# %%
plt.boxplot(df["Salary"])
plt.show()

# %%
df.loc[20] = [0]

# %%
plt.boxplot(df["Salary"])
plt.show()

# %%
df.drop(index = 20, inplace=True)
df.shape
# Out:
# (9, 1)

# %%
# Univariate: Categorical

# %%
df["Dept"] = ['HR','IT','Finance','HT','Finance','IT','HR','Finance','IT']

# %%
df.head()
# Out:
#    Salary     Dept
# 0   25000       HR
# 1   30000       IT
# 2   37000  Finance
# 3   28000       HT
# 4   39000  Finance

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 8
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Salary  9 non-null      int64
#  1   Dept    9 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 216.0+ bytes

# %%
# Pie Chart:

count = df["Dept"].value_counts()
count
# Out:
# Dept
# IT         3
# Finance    3
# HR         2
# HT         1
# Name: count, dtype: int64

# %%
plt.pie(count, labels = count.index, autopct = "%1.1f", explode=[0, 0.1, 0.2, 0.3])
plt.axis("equal")
plt.show()

# %%
#Count plot
plt.bar(count.index, count)
plt.show()

# %%
# Bivariate - numerical - numerical
df["Age"] = [22, 25, 36, 42, 27, 22, 21, 28, 32]

# %%
df.head()
# Out:
#    Salary     Dept  Age
# 0   25000       HR   22
# 1   30000       IT   25
# 2   37000  Finance   36
# 3   28000       HT   42
# 4   39000  Finance   27

# %%
df.shape
# Out:
# (9, 3)

# %%
# Scatter Plot:

plt.scatter(df["Age"],df["Salary"],color = "orange")

# %%
sorted_age = df.sort_values("Age")

# %%
# Line plot:
plt.plot(sorted_age["Age"],df["Salary"])

# %%
# Bar chart:
plt.bar(sorted_age["Age"], df["Salary"],align = "center")
# Out:
# <BarContainer object of 9 artists>

# %%
# Bivariate: Numerical - Categorical

# %%
hr_sal = df[df["Dept"] == "HR"]["Salary"]
hr_sal
# Out:
# 0    25000
# 6    60000
# Name: Salary, dtype: int64

# %%
it_sal = df[df["Dept"] == "IT"]["Salary"]
it_sal
# Out:
# 1    30000
# 5    48000
# 8    58000
# Name: Salary, dtype: int64

# %%
finance_sal = df[df["Dept"] == "Finance"]["Salary"]
finance_sal
# Out:
# 2    37000
# 4    39000
# 7    55000
# Name: Salary, dtype: int64

# %%
plt.boxplot([hr_sal, it_sal, finance_sal], labels = ["HR", "IT", "Finance"])
plt.legend()
plt.show()
# Out:
# /var/folders/b5/lsr7f0hj6s53h_5brm9m7cbm0000gn/T/ipykernel_1664/263939303.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([hr_sal, it_sal, finance_sal], labels = ["HR", "IT", "Finance"])
# /var/folders/b5/lsr7f0hj6s53h_5brm9m7cbm0000gn/T/ipykernel_1664/263939303.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# Pie Chart
salary_by_dept = df.groupby("Dept")["Salary"].sum()
salary_by_dept
# Out:
# Dept
# Finance    131000
# HR          85000
# HT          28000
# IT         136000
# Name: Salary, dtype: int64

# %%
plt.pie(salary_by_dept, labels = salary_by_dept, autopct="%1.1f",shadow=True,explode=[0.1,0.1,0.1,0.1])
plt.axis("equal")
# Out:
# (np.float64(-1.2034463773392814),
#  np.float64(1.1540237646369473),
#  np.float64(-1.199124831988242),
#  np.float64(1.1972644938516606))

# %%
# bar plot
hr_mean = sum(hr_sal)/len(hr_sal)
it_mean = sum(it_sal)/len(it_sal)
fin_mean = sum(finance_sal)/len(finance_sal)

# %%
plt.bar(["HR","Finance","IT"],[hr_mean, it_mean, fin_mean], color = ['green','black','red'])
# Out:
# <BarContainer object of 3 artists>

# %%
# Multivariate Analysis: 3 numerical columns

# %%
df["Experience"] = [1,4,3,2,1,6,2,1,5]

# %%
df.head()
# Out:
#    Salary     Dept  Age  Experience
# 0   25000       HR   22           1
# 1   30000       IT   25           4
# 2   37000  Finance   36           3
# 3   28000       HT   42           2
# 4   39000  Finance   27           1

# %%
# Bubble Plot:
plt.scatter(df["Age"],df["Salary"], s = df["Experience"]*20, color = "orange", edgecolors="black")
plt.title("Age vs Salary")
plt.xlabel("Age")
plt.ylabel("Salary")
plt.grid()
plt.show()

# %%
# 2 numerical and 1 categorical column:

# %%
plt.scatter(df["Age"],df["Salary"], c = df["Dept"],cmap = "rainbow")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Desktop/python datanalysis practice questions/venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:4758, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4757 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4758     colors = mcolors.to_rgba_array(c)
#    4759 except (TypeError, ValueError) as err:
#
# File ~/Desktop/python datanalysis practice questions/venv/lib/python3.13/site-packages/matplotlib/colors.py:515, in to_rgba_array(c, alpha)
#     514 else:
# --> 515     rgba = np.array([to_rgba(cc) for cc in c])
#     517 if alpha is not None:
#
# File ~/Desktop/python datanalysis practice questions/venv/lib/python3.13/site-packages/matplotlib/colors.py:317, in to_rgba(c, alpha)
#     316 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 317     rgba = _to_rgba_no_colorcycle(c, alpha)
#     318     try:
#
# File ~/Desktop/python datanalysis practice questions/venv/lib/python3.13/site-packages/matplotlib/colors.py:394, in _to_rgba_no_colorcycle(c, alpha)
#     393         return c, c, c, alpha if alpha is not None else 1.
# --> 394     raise ValueError(f"Invalid RGBA argument: {orig_c!r}")
#     395 # turn 2-D array into 1-D array
#
# ValueError: Invalid RGBA argument: 'HR'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 plt.scatter(df["Age"],df["Salary"], c = df["Dept"],cmap = "rainbow")
#
# File ~/Desktop/python datanalysis practice questions/venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Desktop/python datanalysis practice questions/venv/lib/python3.13/site-packages/matplotlib/pyplot.py:3948, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, data, **kwargs)
#    3928 @_copy_docstring_and_deprecators(Axes.scatter)
#    3929 def scatter(
#    3930     x: float | ArrayLike,
#    (...)   3946     **kwargs,
#    3947 ) -> PathCollection:
# -> 3948     __ret = gca().scatter(
#    3949         x,
#    3950         y,
#    3951         s=s,
#    3952         c=c,
#    3953         marker=marker,
#    3954         cmap=cmap,
#    3955         norm=norm,
#    3956         vmin=vmin,
#    3957         vmax=vmax,
#    3958         alpha=alpha,
#    3959         linewidths=linewidths,
#    3960         edgecolors=edgecolors,
#    3961         colorizer=colorizer,
#    3962         plotnonfinite=plotnonfinite,
#    3963         **({"data": data} if data is not None else {}),
#    3964         **kwargs,
#    3965     )
#    3966     sci(__ret)
#    3967     return __ret
#
# File ~/Desktop/python datanalysis practice questions/venv/lib/python3.13/site-packages/matplotlib/_api/deprecation.py:453, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     447 if len(args) > name_idx:
#     448     warn_deprecated(
#     449         since, message="Passing the %(name)s %(obj_type)s "
#     450         "positionally is deprecated since Matplotlib %(since)s; the "
#     451         "parameter will become keyword-only in %(removal)s.",
#     452         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 453 return func(*args, **kwargs)
#
# File ~/Desktop/python datanalysis practice questions/venv/lib/python3.13/site-packages/matplotlib/__init__.py:1521, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1518 @functools.wraps(func)
#    1519 def inner(ax, *args, data=None, **kwargs):
#    1520     if data is None:
# -> 1521         return func(
#    1522             ax,
#    1523             *map(cbook.sanitize_sequence, args),
#    1524             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1526     bound = new_sig.bind(ax, *args, **kwargs)
#    1527     auto_label = (bound.arguments.get(label_namer)
#    1528                   or bound.kwargs.get(label_namer))
#
# File ~/Desktop/python datanalysis practice questions/venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:4951, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, colorizer, plotnonfinite, **kwargs)
#    4948 if edgecolors is None:
#    4949     orig_edgecolor = kwargs.get('edgecolor', None)
#    4950 c, colors, edgecolors = \
# -> 4951     self._parse_scatter_color_args(
#    4952         c, edgecolors, kwargs, x.size,
#    4953         get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4955 if plotnonfinite and colors is None:
#    4956     c = np.ma.masked_invalid(c)
#
# File ~/Desktop/python datanalysis practice questions/venv/lib/python3.13/site-packages/matplotlib/axes/_axes.py:4767, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4764             raise invalid_shape_exception(c.size, xsize) from err
#    4765         # Both the mapping *and* the RGBA conversion failed: pretty
#    4766         # severe failure => one may appreciate a verbose feedback.
# -> 4767         raise ValueError(
#    4768             f"'c' argument must be a color, a sequence of colors, "
#    4769             f"or a sequence of numbers, not {c!r}") from err
#    4770 else:
#    4771     if len(colors) not in (0, 1, xsize):
#    4772         # NB: remember that a single color is also acceptable.
#    4773         # Besides *colors* will be an empty array if c == 'none'.
#
# ValueError: 'c' argument must be a color, a sequence of colors, or a sequence of numbers, not 0         HR
# 1         IT
# 2    Finance
# 3         HT
# 4    Finance
# 5         IT
# 6         HR
# 7    Finance
# 8         IT
# Name: Dept, dtype: object
